# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line Chart

# %%
month=['January','February', 'March','April','May','June']
cases=[20,10,30,40,60,50]

plt.figure(figsize=(5,5),facecolor='green')

plt.title('Covid-19 Cases')
plt.xlabel('Month')
plt.ylabel('Cases in Lacs')
plt.grid()

plt.plot(month, cases,label='Confirmed Cases',color='green',marker='o')  #maker=o,^,s
plt.legend()
plt.savefig('Covid Confirmed Case.png')
